# %% [markdown]
# # Description
#
# Es posible usar el programa desde la línea de comandos con:
#
# ```bash
# python src/docs.py
# ```
#
# Es así como lo planee pero también es posible usar el programa desde jupyter notebook: aunque es mas incomodo, puedes usar el archivo `documentacion.ipynb` para ejecutar el programa interactivamente.

# %%
import src.docs as docs

docs.SistemaGestionVentas().ejecutar()
